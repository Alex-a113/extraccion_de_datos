# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex-a113/extraccion_de_datos/blob/main/Actividad2.1(Extraccion_de_datos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Datos_Facturación.csv')
df = df.drop('Unnamed: 0', axis=1)
display(df.head())
# Out:
#   CVE_DOC  CVE_CLPV STATUS  CVE_VEND FECHAELAB   FECHA_DOC         FECHA_ENT  \
# 0  F29414      2465      C       1.0   58:42.0  03/09/2019  03/09/2019 00:00
# 1  F29415      3926      C       1.0   55:14.0  03/09/2019  03/09/2019 00:00
# 2  F29416      3926      C       1.0   25:33.0  03/09/2019  03/09/2019 00:00
# 3  F29417      3926      C       1.0   33:23.0  03/09/2019  03/09/2019 00:00
# 4  F29418      6813      C       2.0   23:45.0  03/09/2019  03/09/2019 00:00
#
#     FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0  18/09/2019    04/09/2019  3980.00      0.0      0.0
# 1  03/10/2019    03/09/2019  1550.00      0.0      0.0
# 2  03/10/2019    03/09/2019  1550.00      0.0      0.0
# 3  03/10/2019    17/09/2019  1550.00      0.0      0.0
# 4  03/09/2019    10/09/2019  2435.44      0.0      0.0

# %%
f1 = df[(df['CVE_CLPV'] >= 1000) & (df['CVE_CLPV'] <= 2000)]
display(f1)
'''
Estamos utilizando la variable CVE_CLPV en la cual la filtramos que sea es mayor o igual a 1000 o es menor o igual a 2000.
'''
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND FECHAELAB   FECHA_DOC  \
# 18     F29432      1965      C       2.0   05:04.0  05/09/2019
# 22     F29436      1965      C       2.0   01:36.0  06/09/2019
# 65     F29479      1240      E       2.0   38:45.0  11/09/2019
# 71     F29485      1965      C       2.0   14:28.0  12/09/2019
# 72     F29486      1965      E       2.0   25:52.0  12/09/2019
# ...       ...       ...    ...       ...       ...         ...
# 10821  F40237      1757      E       2.0   18:17.6  24/02/2023
# 10839  F40255      1583      E       2.0   15:45.8  28/02/2023
# 10845  F40261      1786      E       2.0   15:32.5  28/02/2023
# 10871  F40287      1453      E       1.0   58:23.4  01/03/2023
# 10876  F40292      1082      E       6.0   00:54.8  02/03/2023
#
#               FECHA_ENT   FECHA_VEN FECHA_CANCELA   CAN_TOT  DES_TOT  DES_FIN
# 18     05/09/2019 00:00  20/09/2019    06/09/2019    976.50     0.00      0.0
# ...

# %%
f1.to_csv('Filtro1-CVE_PLV.csv', index=False)

# %%
f2 = df_filtrado = df[~((df["CVE_VEND"] == 4) | (df["CVE_VEND"] == 5))]
display(f2)

'''
Utilizamos la variable CVE_VEND para que no muestre los valores 4 y 5.
'''
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND FECHAELAB   FECHA_DOC  \
# 0      F29414      2465      C       1.0   58:42.0  03/09/2019
# 1      F29415      3926      C       1.0   55:14.0  03/09/2019
# 2      F29416      3926      C       1.0   25:33.0  03/09/2019
# 3      F29417      3926      C       1.0   33:23.0  03/09/2019
# 4      F29418      6813      C       2.0   23:45.0  03/09/2019
# ...       ...       ...    ...       ...       ...         ...
# 10890  F40306      8842      E       2.0   09:39.0  06/03/2023
# 10891  F40307      6218    NaN       2.0   38:42.9  06/03/2023
# 10892     NaN      5926      E       2.0   02:33.4  06/03/2023
# 10893  F40309       361      E       2.0   43:49.6  07/03/2023
# 10894  F40310      3011      E       2.0   45:58.4  07/03/2023
#
#               FECHA_ENT   FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0      03/09/2019 00:00  18/09/2019    04/09/2019  3980.00      0.0      0.0
# ...

# %%
f2.to_csv('Filtro2-CVE_VEND.csv', index=False)

# %%
df["FECHA_ENT"] = pd.to_datetime(df["FECHA_ENT"], dayfirst=True, errors='coerce')
filtro_fecha = df[df["FECHA_ENT"] == pd.to_datetime("2022-02-28")]
display(filtro_fecha)

'''
Filtramos la variable FECHA_ENT para que muestre solo el dia 28 de febrero de
2022 y primero la convertimos a datetime para evitar errores
'''
# Out:
#      CVE_DOC  CVE_CLPV STATUS  CVE_VEND FECHAELAB   FECHA_DOC  FECHA_ENT  \
# 8077  F37493      4598      E       1.0   56:02.5  28/02/2022 2022-02-28
# 8078  F37494      1943      C       2.0   34:00.4  28/02/2022 2022-02-28
# 8081  F37497      1943      C       2.0   05:42.4  28/02/2022 2022-02-28
# 8083  F37499      8573      E       2.0   25:29.8  28/02/2022 2022-02-28
# 8084  F37500      8249      E       2.0   32:46.7  28/02/2022 2022-02-28
# 8090  F37506      1757      E       2.0   23:45.4  28/02/2022 2022-02-28
# 8091  F37507      3108      E       2.0   52:43.4  28/02/2022 2022-02-28
# 8092  F37508      6232      E       2.0   46:56.9  28/02/2022 2022-02-28
# 8095  F37511      8593      E       2.0   20:58.0  28/02/2022 2022-02-28
# 8096  F37512      4766      E       2.0   54:16.3  28/02/2022 2022-02-28
# 8100  F37516      6179      E       3.0   33:54.4  28/02/2022 2022-02-28
# 8103  F37519      5150      E       3.0   09:39.2  28/02/2022 2022-02-28
# ...

# %%
filtro_fecha.to_csv('Filtro3-FECHA_ENT.csv', index=False)

# %%
f4 = df[(df["CAN_TOT"] < 5951.7) | (df["STATUS"] == "E")]
display(f4)

'''
Filtramos las dos variables CAN_TOT y STATUS en la cual filtramos las filas
< 5951.7) o donde el estado es “E”
'''
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND FECHAELAB   FECHA_DOC  FECHA_ENT  \
# 0      F29414      2465      C       1.0   58:42.0  03/09/2019 2019-09-03
# 1      F29415      3926      C       1.0   55:14.0  03/09/2019 2019-09-03
# 2      F29416      3926      C       1.0   25:33.0  03/09/2019 2019-09-03
# 3      F29417      3926      C       1.0   33:23.0  03/09/2019 2019-09-03
# 4      F29418      6813      C       2.0   23:45.0  03/09/2019 2019-09-03
# ...       ...       ...    ...       ...       ...         ...        ...
# 10890  F40306      8842      E       2.0   09:39.0  06/03/2023 2023-03-01
# 10891  F40307      6218    NaN       2.0   38:42.9  06/03/2023 2023-03-06
# 10892     NaN      5926      E       2.0   02:33.4  06/03/2023 2023-03-06
# 10893  F40309       361      E       2.0   43:49.6  07/03/2023 2023-03-07
# 10894  F40310      3011      E       2.0   45:58.4  07/03/2023 2023-03-01
#
#         FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# ...

# %%
f4.to_csv('Filtro4-CAN_TOT.csv', index=False)

# %%
f5 = df[["CVE_DOC", "FECHA_ENT", "FECHA_VEN", "CAN_TOT"]]
display(f5.head(8))

'''
Filtramos las variables CVE_DOC, FECHA_ENT, FECHA_VEN, CAN_TOT en un nuevo dataframe
'''
# Out:
#   CVE_DOC  FECHA_ENT   FECHA_VEN   CAN_TOT
# 0  F29414 2019-09-03  18/09/2019  3980.000
# 1  F29415 2019-09-03  03/10/2019  1550.000
# 2  F29416 2019-09-03  03/10/2019  1550.000
# 3  F29417 2019-09-03  03/10/2019  1550.000
# 4  F29418 2019-09-03  03/09/2019  2435.440
# 5  F29419 2019-09-04  19/09/2019  3979.998
# 6  F29420 2019-09-04  04/09/2019   402.590
# 7  F29421 2019-09-04  04/09/2019   402.590
# '\nFiltramos las variables CVE_DOC, FECHA_ENT, FECHA_VEN, CAN_TOT en un nuevo dataframe\n'

# %%
f5.to_csv('Filtro5-COLUMNAS.csv', index=False)

# %%
f6 = df.iloc[7001:7100]
display(f6.head(8))

'''
Filtramos las filas desde la 7001 a la 7100
'''
# Out:
#       Unnamed: 0 CVE_DOC  CVE_CLPV STATUS  CVE_VEND                FECHAELAB  \
# 9118        9118  F38534    5926.0      E         2  2022-07-06 16:58:48.250
# 9119        9119  F38535    4644.0      E         2  2022-07-06 17:41:30.797
# 9120        9120  F38536    8707.0      E         2  2022-07-06 17:50:49.653
# 9121        9121  F38537    8380.0      E         2  2022-07-06 18:15:05.847
# 9122        9122  F38538    8243.0      E         1  2022-07-07 09:50:53.953
# 9123        9123  F38539      23.0      E         2  2022-07-07 11:47:47.600
# 9124        9124  F38540    5942.0      E         1  2022-07-07 12:30:10.980
# 9125        9125  F38541    8689.0      E         1  2022-07-07 13:29:31.677
#
#        FECHA_DOC  FECHA_ENT   FECHA_VEN FECHA_CANCELA    CAN_TOT  DES_TOT  \
# 9118  2022-07-06 2022-07-04  2022-07-06           NaN  4790.0000      0.0
# 9119  2022-07-06 2022-07-06  2022-07-06           NaN   188.0000      0.0
# ...

# %%
f6.to_csv('Filtro6-FILAS.csv', index=False)

# %%
df = df[df["CVE_VEND"].isin([1, 2])]
f7 = df[["CVE_VEND", "FECHAELAB"]].set_index("CVE_VEND")

print(f7)

'''
FIltramos la variable CVE_VEND en la cual muestre solo los valores 1 y 2.
Seleccionamos las columnas CVE_VEND y FECHAELAB y las mostramos en un nuevo dataframe con el indice CVE_VEND
'''
# Out:
#          FECHAELAB
# CVE_VEND
# 1.0        58:42.0
# 1.0        55:14.0
# 1.0        25:33.0
# 1.0        33:23.0
# 2.0        23:45.0
# ...            ...
# 2.0        09:39.0
# 2.0        38:42.9
# 2.0        02:33.4
# 2.0        43:49.6
# 2.0        45:58.4
#
# [8665 rows x 1 columns]
# '\nFIltramos la variable CVE_VEND en la cual muestre solo los valores 1 y 2.\nSeleccionamos las columnas CVE_VEND y FECHAELAB y las mostramos en un nuevo dataframe con el indice CVE_VEND\n'

# %%
f7.to_csv('Filtro7-INDEX.csv', index=False)
